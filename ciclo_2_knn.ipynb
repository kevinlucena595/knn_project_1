# %% [markdown]
# # Ciclo 02: Aprendizado Supervisionado - Classificação

# %% [markdown]
# ## 1.0 Import Libraries

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics as mt

# %% [markdown]
# ## 1.1 Load Dataset

# %%
dataset_path = './dataset/train.csv'

df = pd.read_csv(dataset_path)

# %%
df.head()
# Out:
#    id_cliente  idade  saldo_atual  divida_atual  renda_anual  \
# 0        1767     21   278.172008       2577.05  24196.89636
# 1       11920     40   268.874152       2465.39  19227.37796
# 2        8910     36   446.643127       1055.29  42822.28223
# 3        4964     58   321.141267        703.05  51786.82600
# 4       10100     35   428.716114        891.29  44626.85346
#
#    valor_em_investimentos  taxa_utilizacao_credito  num_emprestimos  \
# 0              104.306544                31.038763                6
# 1               69.858778                36.917093                5
# 2              134.201478                34.561714                0
# 3              297.350067                31.493561                0
# 4              134.201478                28.028887                2
#
#    num_contas_bancarias  num_cartoes_credito  dias_atraso_dt_venc  \
# 0                     5                    7                   21
# 1                     8                    5                   40
# 2                     3                    6                   26
# 3                     3                    7                   12
# 4                     8                    7                   24
#
#    num_pgtos_atrasados  num_consultas_credito  taxa_juros investe_exterior  \
# 0                   14                      9          15              Não
# 1                   23                     10          18              Não
# 2                   13                      3          15              Sim
# 3                    7                      2           1              Sim
# 4                   10                      8          20              Sim
#
#   pessoa_polit_exp limite_adicional
# 0              Não            Negar
# 1              Não            Negar
# 2              Não            Negar
# 3              Não            Negar
# 4              Não            Negar

# %%
df.loc[: ,'limite_adicional'].unique()
# Out:
# array(['Negar', 'Conceder'], dtype=object)

# %% [markdown]
# ## 1.2 Features Selection

# %%
df.columns
# Out:
# Index(['id_cliente', 'idade', 'saldo_atual', 'divida_atual', 'renda_anual',
#        'valor_em_investimentos', 'taxa_utilizacao_credito', 'num_emprestimos',
#        'num_contas_bancarias', 'num_cartoes_credito', 'dias_atraso_dt_venc',
#        'num_pgtos_atrasados', 'num_consultas_credito', 'taxa_juros',
#        'investe_exterior', 'pessoa_polit_exp', 'limite_adicional'],
#       dtype='object')

# %%
# x = training features
# y = label

features = ['idade', 'saldo_atual', 'divida_atual', 'renda_anual', 'valor_em_investimentos',
            'taxa_utilizacao_credito', 'num_emprestimos', 'num_contas_bancarias', 'num_cartoes_credito',
             'dias_atraso_dt_venc', 'num_pgtos_atrasados', 'num_consultas_credito', 'taxa_juros']
label = 'limite_adicional'

x_train = df.loc[:, features]
y_train = df.loc[:, label]

# %% [markdown]
# ## 1.3 Training

# %%
#training parameters definition
k = 7
knn_classifier = KNeighborsClassifier( n_neighbors = k )

#algorith training
knn_classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred = knn_classifier.predict(x_train)

# %%
df_result = df.copy()
df_result['Classificacao'] = y_pred

# %%
df_result.loc[:, ['id_cliente', 'idade', 'limite_adicional', 'Classificacao']].sample(20)
# Out:
#       id_cliente  idade limite_adicional Classificacao
# 7369        6727     46         Conceder         Negar
# 6698         673     33            Negar         Negar
# 635         3502     50            Negar         Negar
# 3150        8590     19            Negar         Negar
# 5420        5093     41            Negar         Negar
# 351        12361     49            Negar         Negar
# 8725        5311     23            Negar         Negar
# 2405        6836     42            Negar         Negar
# 9302        3416     42            Negar         Negar
# 2878        9230     26            Negar         Negar
# 3264        9395     24            Negar         Negar
# 7443       11340     48            Negar         Negar
# 6234        8544     26            Negar         Negar
# 4755        5641     35            Negar         Negar
# 291         6194     60            Negar         Negar
# 7218        8395     39            Negar         Negar
# 3690        4123     26            Negar         Negar
# 36          8048     23            Negar         Negar
# 3335       10592     31            Negar         Negar
# 3027        3823     50            Negar         Negar

# %% [markdown]
# ## 1.4 Performance

# %%
df.groupby('limite_adicional')['limite_adicional'].count()
# Out:
# limite_adicional
# Conceder    1505
# Negar       7995
# Name: limite_adicional, dtype: int64

# %%
df.loc[:, 'limite_adicional'].value_counts(normalize = True)
# Out:
# limite_adicional
# Negar       0.841579
# Conceder    0.158421
# Name: proportion, dtype: float64

# %%
df_result['acertos'] = df_result.loc[:, ['id_cliente','limite_adicional','Classificacao']].apply(
    lambda x: 1 if x['limite_adicional'] == x['Classificacao'] else 0, axis = 1)

# %%
df_result.loc[:, ['id_cliente','limite_adicional','Classificacao','acertos']].sample(20)
# Out:
#       id_cliente limite_adicional Classificacao  acertos
# 4368        1315         Conceder         Negar        0
# 6453        7040            Negar         Negar        1
# 6624       10425            Negar         Negar        1
# 8679        9444            Negar         Negar        1
# 8740        8502            Negar         Negar        1
# 5552       11005            Negar         Negar        1
# 8421       10369            Negar         Negar        1
# 9069        2438            Negar         Negar        1
# 2214        8569         Conceder      Conceder        1
# 9364        6402         Conceder         Negar        0
# 9113        5687         Conceder         Negar        0
# 2981       11246            Negar      Conceder        0
# 2775        7925            Negar         Negar        1
# 8282        7486            Negar         Negar        1
# 1587       11095         Conceder      Conceder        1
# 8962        8225            Negar         Negar        1
# 5565       11958            Negar         Negar        1
# 2927       10305            Negar         Negar        1
# 7174         970            Negar         Negar        1
# 8538         860            Negar         Negar        1

# %%
corrects = df_result['acertos'].sum()
total = df_result['acertos'].size

accuracy = corrects/total
print( 'Acuracia: {:.2f}%'.format( accuracy * 100) )
# Out:
# Acuracia: 85.91%

# %%
mt.confusion_matrix(y_train, y_pred)
# Out:
# array([[ 369, 1136],
#        [ 203, 7792]])

# %%
accuracy = mt.accuracy_score(y_train, y_pred)
print( 'Acuracia: {:.2f}%'.format( accuracy * 100) )
# Out:
# Acuracia: 85.91%
